# %%
import pandas as pd

# %%
df = pd.read_csv("../data/UNSW_NB15_testing-set.csv")

# %%
df.shape
# Out:
# (82332, 45)

# %%
df["label"].value_counts()
# Out:
# label
# 1    45332
# 0    37000
# Name: count, dtype: int64
